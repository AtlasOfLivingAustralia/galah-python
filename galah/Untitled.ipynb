# %%
import galah
from galah import *

# %%
atlas_counts(group_by=["year","basisOfRecord"], filters="year>2010",expand=True)
# Out:
#     year        basisOfRecord    count
# 0   2011    HUMAN_OBSERVATION  2094450
# 1   2011      LIVING_SPECIMEN     1167
# 2   2011  MACHINE_OBSERVATION   225082
# 3   2011    MATERIAL_CITATION        1
# 4   2011      MATERIAL_SAMPLE    35910
# ..   ...                  ...      ...
# 82  2022  MACHINE_OBSERVATION        7
# 83  2022      MATERIAL_SAMPLE      539
# 84  2022          OBSERVATION      558
# 85  2022           OCCURRENCE     9932
# 86  2022   PRESERVED_SPECIMEN     2989
#
# [87 rows x 3 columns]

# %%
show_all(apis=True)
# Out:
#               atlas        system                 api_name  \
# 0         Australia   collections  collections_collections
# 1         Australia   collections     collections_datasets
# 2         Australia   collections    collections_providers
# 3         Australia  data-quality             profiles_all
# 4         Australia  data-quality          profiles_lookup
# ..              ...           ...                      ...
# 174  United Kingdom       records            records_query
# 175  United Kingdom       records          records_species
# 176  United Kingdom       species      names_search_single
# 177  United Kingdom       species         species_children
# 178  United Kingdom       species           species_lookup
#
#                                                api_url             called_by
# 0         https://collections.ala.org.au/ws/collection  show_all_collections
# 1       https://collections.ala.org.au/ws/dataResource     show_all_datasets
# ...

# %%
search_all(apis="Australia")
# Out:
#         atlas         system                 api_name  \
# 0   Australia    collections  collections_collections
# 21  Australia        spatial           spatial_layers
# 20  Australia        records          records_species
# 19  Australia        records            records_query
# 18  Australia        records      records_occurrences
# 17  Australia        records           records_fields
# 16  Australia        records           records_facets
# 15  Australia        records           records_counts
# 14  Australia        records       records_assertions
# 13  Australia  name-matching      names_search_single
# 12  Australia  name-matching    names_search_multiple
# 11  Australia  name-matching             names_lookup
# 10  Australia         logger           logger_reasons
# 9   Australia          lists             lists_lookup
# 8   Australia          lists                lists_all
# 7   Australia         images           image_metadata
# ...

# %%
atlas_counts(group_by=["year","basisOfRecord"], filters=["year>2010","basisOfRecord=HUMAN_OBSERVATION"],expand=True)
# Out:
#     year      basisOfRecord    count
# 0   2011  HUMAN_OBSERVATION  2094450
# 1   2012  HUMAN_OBSERVATION  2418035
# 2   2013  HUMAN_OBSERVATION  2732566
# 3   2014  HUMAN_OBSERVATION  3137862
# 4   2015  HUMAN_OBSERVATION  3243797
# 5   2016  HUMAN_OBSERVATION  3481567
# 6   2017  HUMAN_OBSERVATION  4311537
# 7   2018  HUMAN_OBSERVATION  5216516
# 8   2019  HUMAN_OBSERVATION  5511393
# 9   2020  HUMAN_OBSERVATION  6291788
# 10  2021  HUMAN_OBSERVATION  7029434
# 11  2022  HUMAN_OBSERVATION  1117289

# %%
galah_select(selectionList=["basisOfRecord","year>2010","cl22"])
# Out:
# 'fields=basisOfRecord%2Cyear>2010%2Ccl22%2C'
